# %%
import pandas as pd

# %%
happiness = pd.read_excel("happiness.xlsx")
happiness
# Out:
#          country  happiness_rank  year
# 0    Switzerland             1.0  2015
# 1        Iceland             2.0  2015
# 2        Denmark             3.0  2015
# 3         Norway             4.0  2015
# 4         Canada             5.0  2015
# ..           ...             ...   ...
# 300      Rwanda*           143.0  2022
# 301     Zimbabwe           144.0  2022
# 302      Lebanon           145.0  2022
# 303  Afghanistan           146.0  2022
# 304          NaN             NaN  2022
#
# [305 rows x 3 columns]

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         304 non-null    object
#  1   happiness_rank  304 non-null    float64
#  2   year            305 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
df = happiness[["country", "happiness_rank", "year"]]
df.sample(10)
# Out:
#                   country  happiness_rank  year
# 231                  Peru            74.0  2022
# 67                Algeria            68.0  2015
# 194                Panama            37.0  2022
# 271              Cambodia           114.0  2022
# 167           New Zealand            10.0  2022
# 135                 Yemen           136.0  2015
# 162           Netherlands             5.0  2022
# 19   United Arab Emirates            20.0  2015
# 156               Burundi           157.0  2015
# 54               Slovenia            55.0  2015

# %%
cty_year_rank_sort = df.sort_values(by=["year", "country"], ascending = True)
cty_year_rank_sort
# Out:
#          country  happiness_rank  year
# 152  Afghanistan           153.0  2015
# 94       Albania            95.0  2015
# 67       Algeria            68.0  2015
# 136       Angola           137.0  2015
# 29     Argentina            30.0  2015
# ..           ...             ...   ...
# 234      Vietnam            77.0  2022
# 289       Yemen*           132.0  2022
# 294       Zambia           137.0  2022
# 301     Zimbabwe           144.0  2022
# 304          NaN             NaN  2022
#
# [305 rows x 3 columns]

# %%
cty_year_rank_sort.sample(60)
# Out:
#                 country  happiness_rank  year
# 121            Ethiopia           122.0  2015
# 61              Croatia            62.0  2015
# 164              Sweden             7.0  2022
# 116               India           117.0  2015
# 153              Rwanda           154.0  2015
# 97   Dominican Republic            98.0  2015
# 227            Malaysia            70.0  2022
# 258          Mozambique           101.0  2022
# 25              Germany            26.0  2015
# 82           Montenegro            82.0  2015
# 152         Afghanistan           153.0  2015
# 11           Costa Rica            12.0  2015
# 24               Panama            25.0  2015
# 124               Kenya           125.0  2015
# 142               Gabon           143.0  2015
# 105          Tajikistan           106.0  2015
# 235       Turkmenistan*            78.0  2022
# 146          Madagascar           147.0  2015
# 196          Guatemala*            39.0  2022
# ...

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Mexico"]
# Out:
#     country  happiness_rank  year
# 13   Mexico            14.0  2015
# 203  Mexico            46.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Venezuela"]
# Out:
#        country  happiness_rank  year
# 22   Venezuela            23.0  2015
# 265  Venezuela           108.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Chile"]
# Out:
#     country  happiness_rank  year
# 26    Chile            27.0  2015
# 201   Chile            44.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Brazil"]
# Out:
#     country  happiness_rank  year
# 15   Brazil            16.0  2015
# 195  Brazil            38.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Argentina"]
# Out:
#        country  happiness_rank  year
# 29   Argentina            30.0  2015
# 214  Argentina            57.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Bolivia"]
# Out:
#      country  happiness_rank  year
# 50   Bolivia            51.0  2015
# 228  Bolivia            71.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Paraguay"]
# Out:
#       country  happiness_rank  year
# 52   Paraguay            53.0  2015
# 230  Paraguay            73.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Uruguay"]
# Out:
#      country  happiness_rank  year
# 31   Uruguay            32.0  2015
# 187  Uruguay            30.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Colombia"]
# Out:
#       country  happiness_rank  year
# 32   Colombia            33.0  2015
# 223  Colombia            66.0  2022

# %%
cty_year_rank_sort[cty_year_rank_sort["country"]=="Ecuador"]
# Out:
#      country  happiness_rank  year
# 47   Ecuador            48.0  2015
# 233  Ecuador            76.0  2022
